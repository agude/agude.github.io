# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import namedtuple
from scipy.interpolate import interp1d
import numpy as np
from itertools import cycle
import matplotlib.patches as mpatches
from matplotlib.ticker import MaxNLocator

# %%
# Set plotting style
plt.style.use("seaborn-white")

WIDTH = 12
HEIGHT = 7

# Hardcoded Colors
YELLOW_JERSEY_COLOR = "gold"
GREEN_JERSEY_COLOR = "#2ca02c"
POLKADOT_JERSEY_COLOR = "#d62728"
WHITE_JERSEY_COLOR = "black"
LANTERNE_ROUGE_COLOR = "darkred"
OTHER_RIDER_COLOR = "grey"

# Default colors
COLORS = plt.rcParams['axes.prop_cycle'].by_key()["color"]

# Remove some colors
grey = '#7f7f7f'
COLORS.remove(grey)

DEFAULT_COLORS = cycle(COLORS)

# %matplotlib inline

# %%
def reset_color_cycle():
    return cycle(COLORS)

# %%
DNF = 999

LAST_STAGE = 21

TOUR_YEAR = 2022

# %% [markdown]
# # Helper functions

# %%
RiderRow = namedtuple("RiderRow", ["rider", "final_place", "x", "y"])

# %%
RiderPlotProp = namedtuple("RiderPlotProp", ["color", "y_nudge"], defaults=[OTHER_RIDER_COLOR, 0.])

# %%
def make_plot_tuples(df, x_col="stage", y_col="gap_seconds", is_sprint=False):
    """Creates a `rider_row` with riders, place, x, and y arrays."""
    # Get stage and final ranks
    rank_col = "rank_gc" if not is_sprint else "rank_sprint"
    finished_riders_by_rank = df[df["stage"]==LAST_STAGE][["rider", rank_col]]
    merged_df = pd.merge(left=df, right=finished_riders_by_rank, how="left", on="rider")
    merged_df = merged_df.rename(columns={f"{rank_col}_x": "stage_rank", f"{rank_col}_y": "final_rank"})
    merged_df["final_rank"] = merged_df["final_rank"].fillna(DNF)
    
    ordered_riders = merged_df[merged_df["stage"]==1].sort_values(["final_rank"])[["rider", "final_rank"]].to_numpy()

    # Get the X, Y values for each rider
    rider_rows = []
    for rider, rank in ordered_riders:
        sub_df = merged_df[merged_df["rider"]==rider]
        x = sub_df[x_col].to_numpy()
        y = sub_df[y_col].to_numpy()
        rider_rows.append(RiderRow(rider, rank, x, y))
        
    return rider_rows

# %%
def get_zorder_alpha(color):
    alpha = 1
    zorder = 0
    
    if color == OTHER_RIDER_COLOR:
        zorder = -1
        alpha = 0.3
    elif color == YELLOW_JERSEY_COLOR:
        zorder = 1
    
    return zorder, alpha

# %%
def plot_lines(x, y, color=OTHER_RIDER_COLOR, label=None):
    zorder, alpha = get_zorder_alpha(color)
  
    if label is None or color == OTHER_RIDER_COLOR:
        label = None

    plt.plot(
        x, y, "-",
        alpha=alpha, 
        zorder=zorder, 
        color=color,
        markersize=7.5,
        linewidth=5,
        label=label,
    )

# %%
def draw_left_legend(ax, special_riders):
    for line in ax.lines:
        label = line.get_label()
        if label.startswith("_"):
            continue
        
        try:
            y_nudge = special_riders[label].y_nudge
        except KeyError:
            y_nudge = 0
        
        color = line.get_color()
        y = line.get_ydata()[-1]
        # Hard-code to the end of the current plot, even if they dropped out
        x = LAST_STAGE 
        
        ax.annotate(
            text=label,
            xy=(x, y),
            xytext=(x+.3, y+y_nudge),
            color=color,
            size=20,
            weight="bold",
            va="center"
        )

# %%
def make_plot(
    rider_rows, 
    top_n=None, 
    max_minute=None, 
    special_riders={}, 
    title=f"Tour de France {TOUR_YEAR}",
    plot_mountains=False,
    plot_yellow=True,
    output_file=None,
    y_max=1,
):
    
    
    fig, ax = plt.subplots(figsize=(WIDTH, HEIGHT))

    # Set titles
    plt.title(title, fontsize=30)
    ax.set_ylabel("Minutes Behind the Leader", fontsize=20)
    ax.set_xlabel("Stage", fontsize=20)

    # Set the ticks to be every stage
    stages = tuple(range(1, 22))
    ax.set_xticks(stages)
    
    ax.tick_params(axis='both', which='major', labelsize=15)
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

    #plot_2d_hist(rider_rows)
    for rider, place, x, y in rider_rows:
        color = OTHER_RIDER_COLOR
        if place == 1 and plot_yellow:
            color = YELLOW_JERSEY_COLOR
        elif rider in special_riders:
            color = special_riders[rider].color
        elif top_n is not None and place > top_n and color == OTHER_RIDER_COLOR:
            continue

        plot_lines(x, y, color, label=rider)

    # Set ticks on the y axis
    if max_minute is not None:
        ax.set_ylim(-0.25, max_minute)
        
    plt.gca().invert_yaxis()
    draw_left_legend(ax, special_riders)
    
    sns.despine(trim=True)
    
    y_min = max(plt.ylim())
    if plot_mountains:
        X_RANGE = plt.xlim()[1] - plt.xlim()[0]
        TEXT_Y_FRAC = 0.032
                
        # The space between tick N and N+1 is when stage N+1 happened, so we start 
        # the shaded area right after the N tick and use a smudge factor to push it forward.
        # This is always why we need to subtract 1 from the start date
        START_SMUDGE = 0.2 - 1
        
        PYRENEES_START = 16 + START_SMUDGE
        PYRENEES_END = 18
        PYRENEES_MID = PYRENEES_START + ((PYRENEES_END - PYRENEES_START) / 2)
        PYRENEES_MID_FRAC = PYRENEES_MID / X_RANGE
        
        ax.axvspan(PYRENEES_START, PYRENEES_END, alpha=0.1, color="grey", zorder=-2, ymax=y_max)
        ax.annotate(
            text="Pyrenees",
            xy=(PYRENEES_MID_FRAC, TEXT_Y_FRAC),
            xycoords="axes fraction",
            color="black",
            size=20,
            va="center",
            ha="center",
        )
        
        ALPS_START = 9 + START_SMUDGE
        ALPS_END = 12
        ALPS_MID = ALPS_START + ((ALPS_END - ALPS_START) / 2)
        ALPS_MID_FRAC = ALPS_MID / X_RANGE
        
        ax.axvspan(ALPS_START, ALPS_END, alpha=0.1, color="grey", zorder=-2, ymax=y_max)
        ax.annotate(
            text="Alps",
            xy=(ALPS_MID_FRAC, TEXT_Y_FRAC),
            xycoords="axes fraction",
            color="black",
            size=20,
            va="center",
            ha="center",
        )

    if not output_file:
        if top_n is not None:
            filename = f"/tmp/{TOUR_YEAR}_tour_de_france_top_{top_n}."
        else:
            filename = f"/tmp/{TOUR_YEAR}_tour_de_france."
    else:
        filename = f"/tmp/{output_file}."

    # Save to disk
    for ext in ("png", "svg"):
        fig.savefig(
            f"{filename}{ext}", bbox_inches="tight"
        )

# %%
def make_sprint_plot(
    rider_rows,
    max_points=None,
    top_n=None,
    special_riders={},
    title=f"Tour de France {TOUR_YEAR}",
    plot_flats=False,
    plot_green=True,
    output_file=None,
):


    fig, ax = plt.subplots(figsize=(WIDTH, HEIGHT))

    # Set titles
    plt.title(title, fontsize=30)
    ax.set_ylabel("Points Behind the Leader", fontsize=20)
    ax.set_xlabel("Stage", fontsize=20)

    # Set the ticks to be every stage
    stages = tuple(range(1, 22))
    ax.set_xticks(stages)

    ax.tick_params(axis='both', which='major', labelsize=15)
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

    #plot_2d_hist(rider_rows)
    for rider, place, x, y in rider_rows:
        color = OTHER_RIDER_COLOR
        if place == 1 and plot_green:
            color = GREEN_JERSEY_COLOR
        elif rider in special_riders:
            color = special_riders[rider].color
        elif top_n is not None and place > top_n and color == OTHER_RIDER_COLOR:
            continue

        plot_lines(x, y, color, label=rider)

    # Set ticks on the y axis
    if max_points is not None:
        ax.set_ylim(-5, max_points)
           

    plt.gca().invert_yaxis()
    draw_left_legend(ax, special_riders)

    sns.despine(trim=True)

    y_min = max(plt.ylim())
    if plot_flats:
        flat_ranges = (
            (2, 3),
            (13, 13),
            (15, 15),
            (19, 19),
            (21, 21),
        )
        Y_MAX=1
        X_RANGE = plt.xlim()[1] - plt.xlim()[0]
        TEXT_Y_FRAC = 0.032
     

        # The space between tick N and N+1 is when stage N+1 happened, so we start 
        # the shaded area right after the N tick and use a smudge factor to push it forward.
        # This is always why we need to subtract 1 from the start date
        START_SMUDGE = 0.2 - 1

        first = True
        for start_stage, end_stage in flat_ranges:
            if first:
                first = False

                mod_start = start_stage + START_SMUDGE
                text_x = mod_start + ((end_stage - mod_start) / 2)
                text_x_frac = text_x / X_RANGE
                
                ax.annotate(
                    text="Flat\nStages",
                    xy=(text_x_frac, TEXT_Y_FRAC),
                    xycoords="axes fraction",
                    color="grey",
                    size=18,
                    va="bottom",
                    ha="center",
                )
                
            ax.axvspan(
                start_stage + START_SMUDGE,
                end_stage,
                alpha=0.1,
                color="grey", 
                zorder=-2, 
                ymax=Y_MAX,
            )

    if not output_file:
        if top_n is not None:
            filename = f"/tmp/{TOUR_YEAR}_tour_de_france_top_{top_n}_points."
        else:
            filename = f"/tmp/{TOUR_YEAR}_tour_de_france_points."
    else:
        filename = f"/tmp/{output_file}."

    # Save to disk
    for ext in ("png", "svg"):
        fig.savefig(
            f"{filename}{ext}", bbox_inches="tight"
        )

# %% [markdown]
# # Load the data

# %%
df = pd.read_json(f"./data/{TOUR_YEAR}-tdf-dataframe.json", orient="table")

# %%
df["gap_minutes"] = df["gap_seconds"] / 60
df["gap_hours"]   = df["gap_seconds"] / 3600

# %%
rider_rows = make_plot_tuples(df, x_col="stage", y_col="gap_minutes")

# %%
rider_rows_sprint = make_plot_tuples(df, x_col="stage", y_col="points_behind_leader", is_sprint=True)

# %%
df
# Out:
#       stage                  rider  rider no.                         team  \
# 0         1            Y. Lampaert         56  Quick-Step Alpha Vinyl Team
# 1         1          Wout van Aert         16                Jumbo - Visma
# 2         1          Tadej Pogačar          1            Uae Team Emirates
# 3         1               F. Ganna         24             Ineos Grenadiers
# 4         1        M. Van Der Poel        101         Alpecin - Deceuninck
# ...     ...                    ...        ...                          ...
# 3336     21              F. Frison        162                 Lotto Soudal
# 3337     21  R. Janse Van Rensburg        164                 Lotto Soudal
# 3338     21              A. Jansen        205      Team Bikeexchange-Jayco
# 3339     21      A. Torres Barcelo         67                Movistar Team
# 3340     21             Caleb Ewan        161                 Lotto Soudal
#
#       rank_gc         times             gap bonus_seconds penalty_seconds  \
# 0           1  00h 15' 17''               -             -               -
# 1           2  00h 15' 22''  + 00h 00' 05''             -               -
# 2           3  00h 15' 24''  + 00h 00' 07''             -               -
# 3           4  00h 15' 27''  + 00h 00' 10''             -               -
# 4           5  00h 15' 30''  + 00h 00' 13''             -               -
# ...       ...           ...             ...           ...             ...
# 3336      131  85h 03' 39''  + 05h 30' 19''             -               -
# 3337      132  85h 04' 45''  + 05h 31' 25''             -               -
# 3338      133  85h 04' 47''  + 05h 31' 27''             -               -
# 3339      134  85h 09' 53''  + 05h 36' 33''             -               -
# 3340      135  85h 14' 02''  + 05h 40' 42''             -         P : 0''
#
#       gap_seconds  times_seconds  rank_sprint  points  points_int  \
# 0             0.0          917.0          1.0  20 PTS          20
# 1             5.0          922.0          2.0  17 PTS          17
# 2             7.0          924.0          3.0  15 PTS          15
# 3            10.0          927.0          4.0  13 PTS          13
# 4            13.0          930.0          5.0  11 PTS          11
# ...           ...            ...          ...     ...         ...
# 3336      19819.0       306219.0         81.0  19 PTS          19
# 3337      19885.0       306285.0        106.0   8 PTS           8
# 3338      19887.0       306287.0          NaN     NaN           0
# 3339      20193.0       306593.0          NaN     NaN           0
# 3340      20442.0       306842.0         34.0  52 PTS          52
#
#       points_behind_leader penalty_points  gap_minutes  gap_hours
# 0                      0.0              -     0.000000   0.000000
# 1                      3.0              -     0.083333   0.001389
# 2                      5.0              -     0.116667   0.001944
# 3                      7.0              -     0.166667   0.002778
# 4                      9.0              -     0.216667   0.003611
# ...                    ...            ...          ...        ...
# 3336                 461.0              -   330.316667   5.505278
# 3337                 472.0              -   331.416667   5.523611
# 3338                 480.0            NaN   331.450000   5.524167
# 3339                 480.0            NaN   336.550000   5.609167
# 3340                 428.0         P : 10   340.700000   5.678333
#
# [3341 rows x 18 columns]

# %% [markdown]
# # Make the plots

# %%
DEFAULT_COLORS = reset_color_cycle()

TOP_SPECIAL_RIDERS = {
    #"Jonas Vingegaard": RiderPlotProp(next(DEFAULT_COLORS)),  # Automaticaly included  
    "Tadej Pogačar": RiderPlotProp(next(DEFAULT_COLORS)),
    "Geraint Thomas": RiderPlotProp(next(DEFAULT_COLORS)),
    "David Gaudu": RiderPlotProp(next(DEFAULT_COLORS)),  
    "Aleksandr Vlasov": RiderPlotProp(next(DEFAULT_COLORS)),
    "Nairo Quintana": RiderPlotProp(next(DEFAULT_COLORS), 0.3),
}

# %%
make_plot(
    rider_rows, 
    top_n=0, 
    max_minute=18.5, 
    special_riders=TOP_SPECIAL_RIDERS,
    title=f"Tour de France {TOUR_YEAR}: Top Contenders",
    plot_mountains=True,
    output_file=f"{TOUR_YEAR}_tour_de_france_top_5"
)

# %%
# Remove green from the sprint colors
SPRINT_COLORS = plt.rcParams['axes.prop_cycle'].by_key()["color"]
SPRINT_COLORS.remove(GREEN_JERSEY_COLOR)
DEFAULT_SPRINT_COLORS = cycle(SPRINT_COLORS)

SPRINT_RIDERS = {
    #"Wout van Aert": RiderPlotProp(GREEN_JERSEY_COLOR), # Automaticaly included
    "Jasper Philipsen": RiderPlotProp(next(DEFAULT_SPRINT_COLORS)),
    "Tadej Pogačar": RiderPlotProp(next(DEFAULT_SPRINT_COLORS)),
    "Christophe Laporte": RiderPlotProp(next(DEFAULT_SPRINT_COLORS), -8),
    "Fabio Jakobsen": RiderPlotProp(next(DEFAULT_SPRINT_COLORS)),
}

# %%
make_sprint_plot(
    rider_rows_sprint, 
    top_n=5, 
    max_points=340, 
    special_riders=SPRINT_RIDERS,
    plot_flats=True,
    title=f"Tour de France {TOUR_YEAR}: Points Leader",
    output_file=f"{TOUR_YEAR}_tour_de_france_top_5_sprint"
)

# %%
DEFAULT_COLORS = reset_color_cycle()

SPECIAL_RIDERS = {
    "Wout van Aert": RiderPlotProp(GREEN_JERSEY_COLOR),
    "Caleb Ewan": RiderPlotProp(LANTERNE_ROUGE_COLOR),
    "Primož Roglič": RiderPlotProp(next(DEFAULT_COLORS)),
}

# %%
make_plot(
    rider_rows, 
    special_riders=SPECIAL_RIDERS,
    plot_mountains=True,
    y_max=0.97,  # Make the mountain shaded areas a little shorter
)
